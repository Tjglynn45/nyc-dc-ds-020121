# %% [markdown]
# # Using APIs and JSON Data

# %% [markdown]
# ## Objectives
# You will be able to:
# * Make an API call to Yelp

# %% [markdown]
# ## Agenda
#
# * Build up an API Call
# * Look at the results

# %%
import requests
import json

# %% [markdown]
# For more information about the request package you can use the following resources:
#
# **Tutorial:** https://realpython.com/python-requests/
#
# **Package Documentation:** https://requests.readthedocs.io/en/master/

# %% [markdown]
# ![](quota.png)

# %% [markdown]
# Let's do a search of businesses on the Yelp API.

# %%
import sys
print(sys.path)
# Out:
# ['C:\\Users\\tj\\documents\\flatiron\\phase_1\\nyc-dc-ds-020121\\Phase_1\\ds-apis_json-main', 'C:\\Users\\tj\\anaconda3\\python38.zip', 'C:\\Users\\tj\\anaconda3\\DLLs', 'C:\\Users\\tj\\anaconda3\\lib', 'C:\\Users\\tj\\anaconda3', '', 'C:\\Users\\tj\\anaconda3\\lib\\site-packages', 'C:\\Users\\tj\\anaconda3\\lib\\site-packages\\win32', 'C:\\Users\\tj\\anaconda3\\lib\\site-packages\\win32\\lib', 'C:\\Users\\tj\\anaconda3\\lib\\site-packages\\Pythonwin', 'C:\\Users\\tj\\anaconda3\\lib\\site-packages\\IPython\\extensions', 'C:\\Users\\tj\\.ipython']

# %%
# set theurl and endpoint we want to hit
url =  'https://api.yelp.com/v3/businesses/search'

# %% [markdown]
# Now that you have an API key, let's enter set that information here so that we can do our searches. Once you have the `api_key` variable, place int in our header.

# %%
client_id = 'Oo7DNF-TUfNLFFtGvsZ4PA'
api_key = 'y1LKwTXxWvNcCMebE1DYMpIMdxxxlXTWGU2C3Lhz1gdS2vyCk7P2WhJ7f0f3AIPyO4cDnRMBfpKo6kwbhhSOw_ltCM-md5YbyiOYrBC8SFRm1s-griQmq-UdKZomYHYx'

# %%
from  keys  import  client_id, api_key
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-13-a43eced8b34d> in <module>
# ----> 1 from  keys  import  client_id, api_key
#
# ModuleNotFoundError: No module named 'keys'

# %%
print(api_key)
# Out:
# y1LKwTXxWvNcCMebE1DYMpIMdxxxlXTWGU2C3Lhz1gdS2vyCk7P2WhJ7f0f3AIPyO4cDnRMBfpKo6kwbhhSOw_ltCM-md5YbyiOYrBC8SFRm1s-griQmq-UdKZomYHYx

# %%
headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }

# %% [markdown]
# We now need to determine our parameters we want to pass.
#
# You must give a specific search term, location and one other paramter to limit your search.
#
# Remember you can search the API documenation to find another parameter to limit your search.
# https://www.yelp.com/developers/documentation/v3/get_started

# %%
# what type of business do you want to search
term = 'Chinese'

#where do you want to perform this search
location = 'Bronx'

# what is your other parameter you want to search against
categories = 'restaurants'

# %%
url_params = {
                "term": term.replace(' ', '+'),
                "location": location.replace(' ', '+'),
                "categories" : categories,
                "limit": 50,
    
            }

# %%
url_params
# Out:
# {'term': 'Chinese',
#  'location': 'Bronx',
#  'categories': 'restaurants',
#  'limit': 50}

# %% [markdown]
# Now that we have all of the parts necessary for an API call, let's put them together.

# %%
response = requests.get(url, headers=headers, params=url_params)

# %%
url
# Out:
# 'https://api.yelp.com/v3/businesses/search'

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# ## The Response
#
# The response of a GET request often has some valuable information, known as a payload, in the message body. Using the attributes and methods of Response, you can view the payload in a variety of different formats.
#
# To see the response’s content in bytes, you use `.content`
#
# You will often want to convert them into a string using a character encoding such as UTF-8. Response will do that for you when you access `.text`
#
# The response is actually serialized JSON content. To get a dictionary, you could take the str you retrieved from `.text` and deserialize it using `json.loads()`. However, a simpler way to accomplish this task is to use `.json()`:

# %%
response.text
# Out:
# '{"businesses": [{"id": "xi_QX5uArqDM4LeL4WIv1Q", "alias": "lis-kitchen-bronx", "name": "Li\'s Kitchen", "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/sVN8idX4C2o_ycdyNS7y3Q/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/lis-kitchen-bronx?adjust_creative=Oo7DNF-TUfNLFFtGvsZ4PA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Oo7DNF-TUfNLFFtGvsZ4PA", "review_count": 35, "categories": [{"alias": "chinese", "title": "Chinese"}], "rating": 4.0, "coordinates": {"latitude": 40.8634617, "longitude": -73.8584642}, "transactions": ["pickup", "delivery"], "price": "$$", "location": {"address1": "2515 Williamsbridge Rd", "address2": "", "address3": "", "city": "Bronx", "zip_code": "10469", "country": "US", "state": "NY", "display_address": ["2515 Williamsbridge Rd", "Bronx, NY 10469"]}, "phone": "+17185191881", "display_phone": "(718) 519-1881", "distance": 1652.539115314742}, {"id": "_iLjlrftSGKvFyG6PXQyAg", "alias": "best-chinese-restaurant-bronx", "name": "Best Chinese Restaurant", "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/rP-gCg3O6ZIKpuUJ5-lHLg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/best-chinese-restaurant-bronx?adjust_creative=Oo7DNF-TUfNLFFtGvsZ4PA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Oo7DNF-TUfNLFFtGvsZ4PA", "review_count": 24, "categories": [{"alias": "chinese", "title": "Chinese"}], "rating": 4.5, "coordinates": {"latitude": 40.88447, "longitude": -73.8315}, "transactions": [], "price": "$", "location": {"address1": "4004A Boston Rd", "address2": "", "address3": "", "city": "Bronx", "zip_code": "10475", "country": "US", "state": "NY", "display_address": ["4004A Boston Rd", "Bronx, NY 10475"]}, "phone": "+17183792438", "display_phone": "(718) 379-2438", "distance": 4762.7264049905525}, {"id": "jVuj54_J9z0w9DjKPoUK2g", "alias": "china-mia-bronx", "name": "China Mia", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/I3TL-puHqvP4ECrFL9LoKw/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/china-mia-bronx?adjust_creative=Oo7DNF-TUfNLFFtGvsZ4PA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Oo7DNF-TUfNLFFtGvsZ4PA", "review_count": 43, "categories": [{"alias": "chinese", "title": "Chinese"}], "rating": 4.0, "coordinates": {"latitude": 40.8581892, "longitude": -73.8675759}, "transactions": ["delivery"], "price": "$", "location": {"address1": "2232 White Plains Rd", "address2": "", "address3": "", "city": "Bronx", "zip_code": "10467", "country": "US", "state": "NY", "display_address": ["2232 White Plains Rd", "Bronx, NY 10467"]}, "phone": "+17187086300", "display_phone": "(718) 708-6300", "distance": 738.1117050536932}, {"id": "F1n2EAqybwEXdEoQQD8tnA", "alias": "empire-wok-new-york-2", "name": "Empire Wok", "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/I8L0lx12zUXie-nHLc7ebA/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/empire-wok-new-york-2?adjust_creative=Oo7DNF-TUfNLFFtGvsZ4PA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Oo7DNF-TUfNLFFtGvsZ4PA", "review_count": 19, "categories": [{"alias": "chinese", "title": "Chinese"}], "rating": 2.5, "coordinates": {"latitude": 40.832786, "longitude": -73.850914}, "transactions": [], "price": "$", "location": {"address1": "1230 Castle Hill Ave", "address2": "", "address3": "", "city": "New York", "zip_code": "10462", "country": "US", "state": "NY", "display_address": ["1230 Castle Hill Ave", "New York, NY 10462"]}, "phone": "+17188282919", "display_phone": "(718) 828-2919", "distance": 2762.1020219040142}, {"id": "rN347NNwQ0hDSlbedzI9BQ", "alias": "kai-sushi-asian-fusion-bronx", "name": "Kai Sushi Asian Fusion", "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/oxO3r9z24A02zlHJHnTZYg/o.jpg", "is_closed": false, "url": "https://www.yelp.com/biz/kai-sushi-asian-fusion-bronx?adjust_creative=Oo7DNF-TUfNLFFtGvsZ4PA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Oo7DNF-TUfNLFFtGvsZ4PA ...

# %%
json.loads(response.text)
# Out:
# {'businesses': [{'id': 'uazg6WhYVOw3jhWCG_MDBg',
#    'alias': 'sup-thai-kitchen-fresh-meadows',
#    'name': 'Sup Thai Kitchen',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/ouTt4JK93LOG0P7fSG1r7g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sup-thai-kitchen-fresh-meadows?adjust_creative=Oo7DNF-TUfNLFFtGvsZ4PA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Oo7DNF-TUfNLFFtGvsZ4PA',
#    'review_count': 373,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7266838, 'longitude': -73.7894371},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '178-19 Union Tpke',
#     'address2': None,
#     'address3': '',
#     'city': 'Fresh Meadows',
#     'zip_code': '11366',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['178-19 Union Tpke', 'Fresh Meadows, NY 11366']},
#    'phone': '+17184874449',
#    'display_phone': '(718) 487-4449',
#    'distance': 5378.159709707153},
#   {'id': 'cegA4jf16vEt7NCQ7cpu2w',
#    'alias': 'kind-fresh-meadows',
#    'name': "Kin'd",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3rnKMO-RGXBAVYXAgffmwQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kind-fresh-meadows?adjust_creative=Oo7DNF-TUfNLFFtGvsZ4PA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Oo7DNF-TUfNLFFtGvsZ4PA',
#    'review_count': 767,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73031, 'longitude': -73.77814},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '192-03 Union Tpke',
#     'address2': '',
#     'address3': None,
#     'city': 'Fresh Meadows',
#     'zip_code': '11366',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['192-03 Union Tpke', 'Fresh Meadows, NY 11366']},
#    'phone': '+17184680888',
#    'display_phone': '(718) 468-0888',
#    'distance': 6273.193942408963},
#   {'id': '0L03onqNwxWLrbb_FCK79A',
#    'alias': 'sripraphai-thai-restaurant-woodside',
#    'name': 'SriPraPhai Thai Restaurant',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DBYmdu8aWPzPWKJzvPm-aQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sripraphai-thai-restaurant-woodside?adjust_creative=Oo7DNF-TUfNLFFtGvsZ4PA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Oo7DNF-TUfNLFFtGvsZ4PA',
#    'review_count': 2380,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7464987, 'longitude': -73.8992328},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '64-13 39th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Woodside',
#     'zip_code': '11377',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['64-13 39th Ave', 'Woodside, NY 11377']},
#    'phone': '+17188999599',
#    'display_phone': '(718) 899-9599',
#    'distance': 4250.747809627073},
#   {'id': 'gr3wUszE1972q0GBkmwEXQ',
#    'alias': 'bangkok-cuisine-forest-hills',
#    'name': 'Bangkok Cuisine',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8vTa_qflOZVu30D0k0HSTg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bangkok-cuisine-forest-hills?adjust_creative=Oo7DNF-TUfNLFFtGvsZ4PA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Oo7DNF-TUfNLFFtGvsZ4PA',
#    'review_count': 421,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.720954, 'longitude': -73.845238},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '10718 70th Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Forest Hills',
#     'zip_code': '11375',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['10718 70th Rd', 'Forest Hills, NY 11375']},
#    'phone': '+17182614005',
#    'display_phone': '(718) 261-4005',
#    'distance': 1329.980593467087},
#   {'id': 'jMb34zhfkqoW866F10hf1Q',
#    'alias': 'grace-thai-restaurant-elmhurst',
#    'name': 'Grace Thai Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/JtXzAAG2jsoperWNGOANSA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/grace-thai-restaurant-elmhurst?adjust_creative=Oo7DNF-TUfNLFFtGvsZ4PA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Oo7DNF-TUfNLFFtGvsZ4PA',
#    'review_count': 52,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.736905, 'longitude': -73.865734},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '5617 Junction Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5617 Junction Blvd', 'Elmhurst, NY 11373']},
#    'phone': '+19294633693',
#    'display_phone': '(929) 463-3693',
#    'distance': 1241.9783887099397},
#   {'id': '3GMHPnrkFAcqffw3T7JSdQ',
#    'alias': 'kitchen-79-jackson-heights',
#    'name': 'Kitchen 79',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ip9F8-pOstZmt7_8T_46Jg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kitchen-79-jackson-heights?adjust_creative=Oo7DNF-TUfNLFFtGvsZ4PA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Oo7DNF-TUfNLFFtGvsZ4PA',
#    'review_count': 629,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.747551, 'longitude': -73.8868866},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '37-70 79th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Jackson Heights',
#     'zip_code': '11372',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['37-70 79th St', 'Jackson Heights, NY 11372']},
#    'phone': '+17188036227',
#    'display_phone': '(718) 803-6227',
#    'distance': 3388.369692606335},
#   {'id': 'fRO4Fwe5uRAajMcTwLbVkA',
#    'alias': 'ayada-thai-elmhurst-2',
#    'name': 'Ayada Thai',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qybFSiSVmsTTXx5fmX3BNQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ayada-thai-elmhurst-2?adjust_creative=Oo7DNF-TUfNLFFtGvsZ4PA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Oo7DNF-TUfNLFFtGvsZ4PA',
#    'review_count': 1222,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7433662414551,
#     'longitude': -73.8876037597656},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '7708 Woodside Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7708 Woodside Ave', 'Elmhurst, NY 11373']},
#    'phone': '+17184240844',
#    'display_phone': '(718) 424-0844',
#    'distance': 3222.317210809843},
#   {'id': '-YazuZbXAM_NOny8LpLQpQ',
#    'alias': 'bkny-thai-restaurant-bayside',
#    'name': 'BKNY Thai Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/glVWdfDHW-eu4KhXWP3QMw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bkny-thai-restaurant-bayside?adjust_creative=Oo7DNF-TUfNLFFtGvsZ4PA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Oo7DNF-TUfNLFFtGvsZ4PA',
#    'review_count': 1317,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7530184239866,
#     'longitude': -73.780074009384},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '47-11 Francis Lewis Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Bayside',
#     'zip_code': '11361',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['47-11 Francis Lewis Blvd', 'Bayside, NY 11361']},
#    'phone': '+17182811900',
#    'display_phone': '(718) 281-1900',
#    'distance': 6582.441577772174},
#   {'id': '1E7lCNaRAM1Da0vkt5rcvw',
#    'alias': 'thai-mission-maspeth',
#    'name': 'Thai Mission',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OTi0qCJS2HAyviRUwg-Qtw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-mission-maspeth?adjust_creative=Oo7DNF-TUfNLFFtGvsZ4PA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Oo7DNF-TUfNLFFtGvsZ4PA',
#    'review_count': 29,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.72779, 'longitude': -73.89279},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '70-11 Grand Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Maspeth',
#     'zip_code': '11378',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['70-11 Grand Ave', 'Maspeth, NY 11378']},
#    'phone': '+19293280328',
#    'display_phone': '(929) 328-0328',
#    'distance': 3390.6012918832753},
#   {'id': '1ubEg-rrSE8IWXl6lJzIGw',
#    'alias': 'nur-thai-rego-park',
#    'name': 'Nur Thai',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wKL4Mnmig42Youp-9eYUIg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/nur-thai-rego-park?adjust_creative=Oo7DNF-TUfNLFFtGvsZ4PA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Oo7DNF-TUfNLFFtGvsZ4PA',
#    'review_count': 561,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7235516378586,
#     'longitude': -73.868817789544},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '63-32 Woodhaven Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Rego Park',
#     'zip_code': '11374',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['63-32 Woodhaven Blvd', 'Rego Park, NY 11374']},
#    'phone': '+17182556141',
#    'display_phone': '(718) 255-6141',
#    'distance': 1608.1819342053043},
#   {'id': 'OVAV0k2O1kqeuRFyt95qzg',
#    'alias': 'ma-kin-middle-village-3',
#    'name': 'Ma Kin',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/HKS9ClA3DITKpnzWjhFm6w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ma-kin-middle-village-3?adjust_creative=Oo7DNF-TUfNLFFtGvsZ4PA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Oo7DNF-TUfNLFFtGvsZ4PA',
#    'review_count': 92,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7130368, 'longitude': -73.8775219},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '7419 Metropolitan Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Middle Village',
#     'zip_code': '11379',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7419 Metropolitan Ave', 'Middle Village, NY 11379']},
#    'phone': '+13475071234',
#    'display_phone': '(347) 507-1234',
#    'distance': 2915.288989938397},
#   {'id': 'a-Bq_yXFVk2PptoWpmry3w',
#    'alias': 'pye-boat-noodle-astoria',
#    'name': 'Pye Boat Noodle',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/jxPnZAwHuRciVqUAd14P4Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pye-boat-noodle-astoria?adjust_creative=Oo7DNF-TUfNLFFtGvsZ4PA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Oo7DNF-TUfNLFFtGvsZ4PA',
#    'review_count': 837,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76043, 'longitude': -73.92152},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '35-13 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11106',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['35-13 Broadway', 'Astoria, NY 11106']},
#    'phone': '+17186852329',
#    'display_phone': '(718) 685-2329',
#    'distance': 6625.086426070104},
#   {'id': 'oNN202L_XcNM-tuDHlgkfg',
#    'alias': 'boon-chu-thai-place-elmhurst',
#    'name': 'Boon Chu Thai Place',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/0ffVw7NKAcTDUIPfd5tUwA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boon-chu-thai-place-elmhurst?adjust_creative=Oo7DNF-TUfNLFFtGvsZ4PA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Oo7DNF-TUfNLFFtGvsZ4PA',
#    'review_count': 313,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.740638, 'longitude': -73.879645},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '83-18 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['83-18 Broadway', 'Elmhurst, NY 11373']},
#    'phone': '+17188986836',
#    'display_phone': '(718) 898-6836',
#    'distance': 2477.7303260455205},
#   {'id': 'STx4mlpKJVrjd6eZu4yDIw',
#    'alias': 'heng-thai-long-island-city',
#    'name': 'Heng Thai',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TNglrhhC7IGOBrdkTu-h-g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/heng-thai-long-island-city?adjust_creative=Oo7DNF-TUfNLFFtGvsZ4PA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Oo7DNF-TUfNLFFtGvsZ4PA',
#    'review_count': 10,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.74491469312005,
#     'longitude': -73.94774386999885},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '23-06 Jackson Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['23-06 Jackson Ave', 'Long Island City, NY 11101']},
#    'phone': '+17187060999',
#    'display_phone': '(718) 706-0999',
#    'distance': 8134.151172667756},
#   {'id': '5pzc2GdvdmqiLRSdjHnnKw',
#    'alias': 'bangkok-avenue-little-neck-2',
#    'name': 'Bangkok Avenue',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-6MNVU7V930qB3PvdLHKAw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bangkok-avenue-little-neck-2?adjust_creative=Oo7DNF-TUfNLFFtGvsZ4PA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Oo7DNF-TUfNLFFtGvsZ4PA',
#    'review_count': 86,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.77135, 'longitude': -73.73529},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '253-21 Northern Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Little Neck',
#     'zip_code': '11362',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['253-21 Northern Blvd', 'Little Neck, NY 11362']},
#    'phone': '+19143033388',
#    'display_phone': '(914) 303-3388',
#    'distance': 10849.613791106447},
#   {'id': '1svF14BUYt_Wc0XA3nMxdw',
#    'alias': 'cha-lom-thai-flushing',
#    'name': 'Cha Lom Thai',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/LUcuIr0hXhAy8DMUMbClFA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cha-lom-thai-flushing?adjust_creative=Oo7DNF-TUfNLFFtGvsZ4PA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Oo7DNF-TUfNLFFtGvsZ4PA',
#    'review_count': 59,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7663429058334,
#     'longitude': -73.7893586550144},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '33-47 Francis Lewis Blvd',
#     'address2': None,
#     'address3': '',
#     'city': 'Flushing',
#     'zip_code': '11358',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['33-47 Francis Lewis Blvd', 'Flushing, NY 11358']},
#    'phone': '+17182696821',
#    'display_phone': '(718) 269-6821',
#    'distance': 6606.083966623151},
#   {'id': 'PPQSf_1JWkbjFHi1S0nSNA',
#    'alias': 'lamoon-elmhurst',
#    'name': 'Lamoon',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/YNrzpdKbmrGLFOtPUwFW6Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lamoon-elmhurst?adjust_creative=Oo7DNF-TUfNLFFtGvsZ4PA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Oo7DNF-TUfNLFFtGvsZ4PA',
#    'review_count': 268,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.742890245749, 'longitude': -73.883034010715},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '8140 Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8140 Broadway', 'Elmhurst, NY 11373']},
#    'phone': '+19177451168',
#    'display_phone': '(917) 745-1168',
#    'distance': 2843.1620995374224},
#   {'id': 'Ve_iFpnhL8zN789ZL2jnxQ',
#    'alias': 'uthai-rego-park',
#    'name': 'UThai',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/EyX6yAydMLYFXZc7dY7PRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/uthai-rego-park?adjust_creative=Oo7DNF-TUfNLFFtGvsZ4PA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Oo7DNF-TUfNLFFtGvsZ4PA',
#    'review_count': 219,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7282415, 'longitude': -73.8639467},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '63-55 Wetherole St',
#     'address2': None,
#     'address3': '',
#     'city': 'Rego Park',
#     'zip_code': '11374',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['63-55 Wetherole St', 'Rego Park, NY 11374']},
#    'phone': '+17188971575',
#    'display_phone': '(718) 897-1575',
#    'distance': 1001.8808045720075},
#   {'id': 'tVB11pOiDhPWlt_o6ylMNg',
#    'alias': 'enthaice-thai-kitchen-astoria',
#    'name': 'Enthaice Thai Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/poiYY93PvnCGFXQAEvO-Ng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/enthaice-thai-kitchen-astoria?adjust_creative=Oo7DNF-TUfNLFFtGvsZ4PA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Oo7DNF-TUfNLFFtGvsZ4PA',
#    'review_count': 695,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'chicken_wings', 'title': 'Chicken Wings'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7630889337809,
#     'longitude': -73.9213237166405},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '33-20 31st Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Astoria',
#     'zip_code': '11106',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['33-20 31st Ave', 'Astoria, NY 11106']},
#    'phone': '+17189321111',
#    'display_phone': '(718) 932-1111',
#    'distance': 6755.95967403878},
#   {'id': 'inftQdKaEEiqQ323AlomXg',
#    'alias': 'dek-sen-elmhurst-2',
#    'name': 'Dek Sen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VV_1YWKJXD_BEvAfQ2-wGw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dek-sen-elmhurst-2?adjust_creative=Oo7DNF-TUfNLFFtGvsZ4PA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Oo7DNF-TUfNLFFtGvsZ4PA',
#    'review_count': 278,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.741714, 'longitude': -73.878689},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '8608 Whitney Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8608 Whitney Ave', 'Elmhurst, NY 11373']},
#    'phone': '+17182055181',
#    'display_phone': '(718) 205-5181',
#    'distance': 2452.1963359930987},
#   {'id': 'a23bfZBVjIhV32Em4hKHAA',
#    'alias': 'the-buffs-long-island-city-4',
#    'name': 'The Buffs',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/lQID-gz3kJ6Gw-Yr8rLVKQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-buffs-long-island-city-4?adjust_creative=Oo7DNF-TUfNLFFtGvsZ4PA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Oo7DNF-TUfNLFFtGvsZ4PA',
#    'review_count': 106,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7556342, 'longitude': -73.9417121},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1313 40th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1313 40th Ave', 'Long Island City, NY 11101']},
#    'phone': '+17183612362',
#    'display_phone': '(718) 361-2362',
#    'distance': 7918.772733558018},
#   {'id': 'CpY77cDN1KS5EdiXMmWovw',
#    'alias': 'house-of-thai-long-island-city-4',
#    'name': 'House of Thai',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/uZJDECEq7QBfrSIfyrPsRQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/house-of-thai-long-island-city-4?adjust_creative=Oo7DNF-TUfNLFFtGvsZ4PA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Oo7DNF-TUfNLFFtGvsZ4PA',
#    'review_count': 301,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7535257695712,
#     'longitude': -73.9377629319284},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2501 40th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Long Island City',
#     'zip_code': '11101',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2501 40th Ave', 'Long Island City, NY 11101']},
#    'phone': '+19295220247',
#    'display_phone': '(929) 522-0247',
#    'distance': 7562.962070152043},
#   {'id': 'PyaeHq_UAu6nazGiy0XAnw',
#    'alias': 'ginger-and-lemongrass-whitestone',
#    'name': 'Ginger and Lemongrass',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rc7pZR40ZmAVzeenf48eZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ginger-and-lemongrass-whitestone?adjust_creative=Oo7DNF-TUfNLFFtGvsZ4PA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Oo7DNF-TUfNLFFtGvsZ4PA',
#    'review_count': 801,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7892691, 'longitude': -73.813717},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1253 150th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Whitestone',
#     'zip_code': '11357',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1253 150th St', 'Whitestone, NY 11357']},
#    'phone': '+13477324720',
#    'display_phone': '(347) 732-4720',
#    'distance': 7222.985916370918},
#   {'id': 'yCJHIM-PWl54K53ACOpoNg',
#    'alias': 'hug-esan-elmhurst',
#    'name': 'Hug Esan',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/6solnO-f4-uAP7irlf1MZA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hug-esan-elmhurst?adjust_creative=Oo7DNF-TUfNLFFtGvsZ4PA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Oo7DNF-TUfNLFFtGvsZ4PA',
#    'review_count': 169,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7436465, 'longitude': -73.8873753},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '77-16 Woodside Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['77-16 Woodside Ave', 'Elmhurst, NY 11373']},
#    'phone': '+19293280392',
#    'display_phone': '(929) 328-0392',
#    'distance': 3209.1609507515063},
#   {'id': 'm2_ZNFos5ugAwe8ft8eaEw',
#    'alias': 'eim-khao-mun-kai-elmhurst-elmhurst',
#    'name': 'Eim Khao Mun Kai Elmhurst',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JqeuGqrZxCPGVowAEs8XFQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/eim-khao-mun-kai-elmhurst-elmhurst?adjust_creative=Oo7DNF-TUfNLFFtGvsZ4PA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Oo7DNF-TUfNLFFtGvsZ4PA',
#    'review_count': 457,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'hainan', 'title': 'Hainan'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7429414097644,
#     'longitude': -73.8832733356575},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '81-32 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['81-32 Broadway', 'Elmhurst, NY 11373']},
#    'phone': '+17184247156',
#    'display_phone': '(718) 424-7156',
#    'distance': 2863.74521041377},
#   {'id': 'kXuubLd6s3GidpqU3psPdw',
#    'alias': 'chao-thai-elmhurst-3',
#    'name': 'Chao Thai',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Sq1y11AFR9zp81X0aH9vKw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chao-thai-elmhurst-3?adjust_creative=Oo7DNF-TUfNLFFtGvsZ4PA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Oo7DNF-TUfNLFFtGvsZ4PA',
#    'review_count': 379,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7414656, 'longitude': -73.8801273},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '8503 Whitney Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8503 Whitney Ave', 'Elmhurst, NY 11373']},
#    'phone': '+17184244999',
#    'display_phone': '(718) 424-4999',
#    'distance': 2568.855535856452},
#   {'id': 'hA5QUlrSjpxMZ90Kof0bgA',
#    'alias': 'khao-kang-elmhurst',
#    'name': 'Khao Kang',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vfRK27R36XLI4wHpZr6bHQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/khao-kang-elmhurst?adjust_creative=Oo7DNF-TUfNLFFtGvsZ4PA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Oo7DNF-TUfNLFFtGvsZ4PA',
#    'review_count': 244,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.743269, 'longitude': -73.888039},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '7620 Woodside Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7620 Woodside Ave', 'Elmhurst, NY 11373']},
#    'phone': '+17188061807',
#    'display_phone': '(718) 806-1807',
#    'distance': 3242.7336966969283},
#   {'id': 'a5H9p1B6m6WPVjakPylvdA',
#    'alias': 'spicy-shallot-elmhurst',
#    'name': 'Spicy Shallot',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/OzUSMfiNLzDNthJuYxni0Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/spicy-shallot-elmhurst?adjust_creative=Oo7DNF-TUfNLFFtGvsZ4PA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Oo7DNF-TUfNLFFtGvsZ4PA',
#    'review_count': 633,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7437053273707,
#     'longitude': -73.8878916857991},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '7701 Woodside Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7701 Woodside Ave', 'Elmhurst, NY 11373']},
#    'phone': '+17186725266',
#    'display_phone': '(718) 672-5266',
#    'distance': 3251.3867012082496},
#   {'id': 'rehmlZmUNL2AthW-VTXJJQ',
#    'alias': 'tasty-thai-ridgewood',
#    'name': 'Tasty Thai',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/NX0ocs11fl3Dj1kTmpBrRw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tasty-thai-ridgewood?adjust_creative=Oo7DNF-TUfNLFFtGvsZ4PA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Oo7DNF-TUfNLFFtGvsZ4PA',
#    'review_count': 86,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.69984, 'longitude': -73.89958},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '72-04 Forest Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Ridgewood',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['72-04 Forest Ave', 'Ridgewood, NY 11385']},
#    'phone': '+19179090937',
#    'display_phone': '(917) 909-0937',
#    'distance': 5281.3840549926945},
#   {'id': 'zRQNaDUoWTInc2tqndSJVA',
#    'alias': 'thai-101-bayside',
#    'name': 'Thai 101',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/dvejY_8barqkhtUQt35Hkw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-101-bayside?adjust_creative=Oo7DNF-TUfNLFFtGvsZ4PA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Oo7DNF-TUfNLFFtGvsZ4PA',
#    'review_count': 306,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.76488, 'longitude': -73.77133},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '39-15 Bell Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Bayside',
#     'zip_code': '11361',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['39-15 Bell Blvd', 'Bayside, NY 11361']},
#    'phone': '+17186318600',
#    'display_phone': '(718) 631-8600',
#    'distance': 7803.89291133938},
#   {'id': 'YMcDo3UccCPvIJrQ5Yt9Yw',
#    'alias': 'chám-thai-cuisine-ridgewood',
#    'name': 'Chám Thai Cuisine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_INscq_GSjWwiY03XfcQbA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ch%C3%A1m-thai-cuisine-ridgewood?adjust_creative=Oo7DNF-TUfNLFFtGvsZ4PA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Oo7DNF-TUfNLFFtGvsZ4PA',
#    'review_count': 48,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.7025939, 'longitude': -73.901464},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '881 Woodward Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Ridgewood',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['881 Woodward Ave', 'Ridgewood, NY 11385']},
#    'phone': '+17188944404',
#    'display_phone': '(718) 894-4404',
#    'distance': 5205.517479140647},
#   {'id': 'wEawMdWT7UtZjEmmMTBiGA',
#    'alias': 'saranrom-thai-elmhurst-2',
#    'name': 'Saranrom Thai',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kfH2mX_qFCnGegh9CUY_rg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/saranrom-thai-elmhurst-2?adjust_creative=Oo7DNF-TUfNLFFtGvsZ4PA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Oo7DNF-TUfNLFFtGvsZ4PA',
#    'review_count': 32,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7431528, 'longitude': -73.8836694},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '8110 Broadway',
#     'address2': None,
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['8110 Broadway', 'Elmhurst, NY 11373']},
#    'phone': '+19178326672',
#    'display_phone': '(917) 832-6672',
#    'distance': 2905.2906392679156},
#   {'id': 'OR9oqAJW-U5ZnqhwH12Nuw',
#    'alias': 'khao-nom-elmhurst',
#    'name': 'Khao Nom',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/fiPmRRzFIz4WRhuyAyGXXQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/khao-nom-elmhurst?adjust_creative=Oo7DNF-TUfNLFFtGvsZ4PA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Oo7DNF-TUfNLFFtGvsZ4PA',
#    'review_count': 116,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7432731562959,
#     'longitude': -73.8879961885031},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '42-06 77th St',
#     'address2': '',
#     'address3': None,
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['42-06 77th St', 'Elmhurst, NY 11373']},
#    'phone': '+19292080108',
#    'display_phone': '(929) 208-0108',
#    'distance': 3250.841753204315},
#   {'id': 'toykv8K0yg8qtvZSXRQ5bg',
#    'alias': 'pochana-thai-kitchen-astoria-2',
#    'name': 'Pochana Thai Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/5hfYhHZOsD9SRICjUaFpYQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pochana-thai-kitchen-astoria-2?adjust_creative=Oo7DNF-TUfNLFFtGvsZ4PA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Oo7DNF-TUfNLFFtGvsZ4PA',
#    'review_count': 193,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.765733, 'longitude': -73.91932},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '33-16 30th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['33-16 30th Ave', 'Astoria, NY 11103']},
#    'phone': '+17189569559',
#    'display_phone': '(718) 956-9559',
#    'distance': 6773.2440684776475},
#   {'id': 'dnCRiUZWgu5ZI4Q-Z-az6Q',
#    'alias': 'thai-diva-cuisine-woodside-3',
#    'name': 'Thai Diva Cuisine',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/FAxltkvgVnPp87i9Uq90Ew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-diva-cuisine-woodside-3?adjust_creative=Oo7DNF-TUfNLFFtGvsZ4PA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Oo7DNF-TUfNLFFtGvsZ4PA',
#    'review_count': 140,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'soup', 'title': 'Soup'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7414512, 'longitude': -73.9190131},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '45-53 46th St',
#     'address2': None,
#     'address3': '',
#     'city': 'Woodside',
#     'zip_code': '11377',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['45-53 46th St', 'Woodside, NY 11377']},
#    'phone': '+19292080282',
#    'display_phone': '(929) 208-0282',
#    'distance': 5684.506606279269},
#   {'id': 'ipxeCjihDqXTMkuPe-CQ4A',
#    'alias': 'arunee-thai-jackson-heights',
#    'name': 'Arunee Thai',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/yBzXFJre13F2BtJNRiWAlA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/arunee-thai-jackson-heights?adjust_creative=Oo7DNF-TUfNLFFtGvsZ4PA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Oo7DNF-TUfNLFFtGvsZ4PA',
#    'review_count': 317,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7494503, 'longitude': -73.8873621},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '78-23 37th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Jackson Heights',
#     'zip_code': '11372',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['78-23 37th Ave', 'Jackson Heights, NY 11372']},
#    'phone': '+17182055559',
#    'display_phone': '(718) 205-5559',
#    'distance': 3529.3232402943213},
#   {'id': '8-dc942sz-prIeepAkHLJA',
#    'alias': 'zenith-thai-restaurant-ridgewood',
#    'name': 'Zenith Thai Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/P5WjD6_4bZyV6AVgkeceaw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zenith-thai-restaurant-ridgewood?adjust_creative=Oo7DNF-TUfNLFFtGvsZ4PA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Oo7DNF-TUfNLFFtGvsZ4PA',
#    'review_count': 113,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7023726, 'longitude': -73.8952926},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '7002 Fresh Pond Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Ridgewood',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7002 Fresh Pond Rd', 'Ridgewood, NY 11385']},
#    'phone': '+17184978899',
#    'display_phone': '(718) 497-8899',
#    'distance': 4825.743443483346},
#   {'id': 'Eyn7hQENF8R9DrBwBHO6lQ',
#    'alias': 'pata-cafe-elmhurst',
#    'name': 'Pata Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/XaAZQtUInh_RNGATh7ImpA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pata-cafe-elmhurst?adjust_creative=Oo7DNF-TUfNLFFtGvsZ4PA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Oo7DNF-TUfNLFFtGvsZ4PA',
#    'review_count': 73,
#    'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7326341, 'longitude': -73.8769762},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '5614 Van Horn St',
#     'address2': None,
#     'address3': '',
#     'city': 'Elmhurst',
#     'zip_code': '11373',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['5614 Van Horn St', 'Elmhurst, NY 11373']},
#    'phone': '+13474697142',
#    'display_phone': '(347) 469-7142',
#    'distance': 2013.709004982964},
#   {'id': '1wdJ1vJR_Z1vJebQGlZU3Q',
#    'alias': 'krung-tep-thai-bistro-great-neck-plaza',
#    'name': 'Krung Tep Thai Bistro',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Nwo0m4I7O95U2Kp9-JRoIQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/krung-tep-thai-bistro-great-neck-plaza?adjust_creative=Oo7DNF-TUfNLFFtGvsZ4PA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Oo7DNF-TUfNLFFtGvsZ4PA',
#    'review_count': 223,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.78661, 'longitude': -73.725858},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '23 S Middle Neck Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Great Neck Plaza',
#     'zip_code': '11021',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['23 S Middle Neck Rd', 'Great Neck Plaza, NY 11021']},
#    'phone': '+15164989889',
#    'display_phone': '(516) 498-9889',
#    'distance': 12337.29866702809},
#   {'id': '2ZBEE_MJeRdLD1NLiNTnCQ',
#    'alias': 'thailands-center-point-woodside-2',
#    'name': "Thailand's Center Point",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/o99eLojQrJOaEe1keKZEug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thailands-center-point-woodside-2?adjust_creative=Oo7DNF-TUfNLFFtGvsZ4PA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Oo7DNF-TUfNLFFtGvsZ4PA',
#    'review_count': 196,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.746738, 'longitude': -73.900162},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '63-19 39th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Woodside',
#     'zip_code': '11377',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['63-19 39th Ave', 'Woodside, NY 11377']},
#    'phone': '+17186516888',
#    'display_phone': '(718) 651-6888',
#    'distance': 4333.1887147697735},
#   {'id': 'ET4xGd-SQ6gs9lce4xVpQg',
#    'alias': 'tum-thai-cuisine-rockville-centre',
#    'name': 'Tum Thai Cuisine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0keHJi1yLq97gnDyCeM7UQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/tum-thai-cuisine-rockville-centre?adjust_creative=Oo7DNF-TUfNLFFtGvsZ4PA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Oo7DNF-TUfNLFFtGvsZ4PA',
#    'review_count': 641,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.65591, 'longitude': -73.64574},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '274 Merrick Rd',
#     'address2': '',
#     'address3': '',
#     'city': 'Rockville Centre',
#     'zip_code': '11570',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['274 Merrick Rd', 'Rockville Centre, NY 11570']},
#    'phone': '+15165435078',
#    'display_phone': '(516) 543-5078',
#    'distance': 19384.513491944435},
#   {'id': 'nu239sXQUGjcGFhZ3AdJmQ',
#    'alias': 'erawan-thai-cuisine-bayside',
#    'name': 'Erawan Thai Cuisine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/x_vmcrpshZxNmtw9sKHzwA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/erawan-thai-cuisine-bayside?adjust_creative=Oo7DNF-TUfNLFFtGvsZ4PA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Oo7DNF-TUfNLFFtGvsZ4PA',
#    'review_count': 346,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.761821, 'longitude': -73.769775},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '4231 Bell Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Bayside',
#     'zip_code': '11361',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4231 Bell Blvd', 'Bayside, NY 11361']},
#    'phone': '+17184282112',
#    'display_phone': '(718) 428-2112',
#    'distance': 7766.294526950914},
#   {'id': '2pJ782hnKTK0MWbc0H7EDw',
#    'alias': 'ditmars-thai-astoria',
#    'name': 'Ditmars Thai',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/P4ei6AZRi77oR6HcHLJMbg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ditmars-thai-astoria?adjust_creative=Oo7DNF-TUfNLFFtGvsZ4PA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Oo7DNF-TUfNLFFtGvsZ4PA',
#    'review_count': 12,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.77473, 'longitude': -73.90825},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '35-13 Ditmars Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Astoria',
#     'zip_code': '11105',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['35-13 Ditmars Blvd', 'Astoria, NY 11105']},
#    'phone': '+17182694549',
#    'display_phone': '(718) 269-4549',
#    'distance': 6703.073797984971},
#   {'id': 'QWskQ2QpR8bmza2FRFziOQ',
#    'alias': 'asian-fortune-restaurant-forest-hills',
#    'name': 'Asian Fortune Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Av0ZXxYsKSXnZ8z182gh0g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/asian-fortune-restaurant-forest-hills?adjust_creative=Oo7DNF-TUfNLFFtGvsZ4PA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Oo7DNF-TUfNLFFtGvsZ4PA',
#    'review_count': 114,
#    'categories': [{'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7244621, 'longitude': -73.8493213},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '103-35 Queens Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Forest Hills',
#     'zip_code': '11375',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['103-35 Queens Blvd', 'Forest Hills, NY 11375']},
#    'phone': '+17188306313',
#    'display_phone': '(718) 830-6313',
#    'distance': 851.8262088216507},
#   {'id': 'khvnn7cpiYSpe80ue5YLvg',
#    'alias': 'ddee-thai-astoria',
#    'name': 'Ddee Thai',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/mVpYungatdQ1AFuujOjTdA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ddee-thai-astoria?adjust_creative=Oo7DNF-TUfNLFFtGvsZ4PA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Oo7DNF-TUfNLFFtGvsZ4PA',
#    'review_count': 37,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.762909, 'longitude': -73.91325},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '42-06 30th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Astoria',
#     'zip_code': '11103',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['42-06 30th Ave', 'Astoria, NY 11103']},
#    'phone': '+17186261222',
#    'display_phone': '(718) 626-1222',
#    'distance': 6173.635697332506},
#   {'id': 'MxMWPaC30sRkPKit_Omz2A',
#    'alias': 'khun-noo-thai-noodle-house-woodside',
#    'name': 'Khun Noo Thai Noodle House',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/85O4rR5ovWEeOa7sy1El2Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/khun-noo-thai-noodle-house-woodside?adjust_creative=Oo7DNF-TUfNLFFtGvsZ4PA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Oo7DNF-TUfNLFFtGvsZ4PA',
#    'review_count': 51,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74568, 'longitude': -73.91261},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '51-20 Skillman Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Woodside',
#     'zip_code': '11377',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['51-20 Skillman Ave', 'Woodside, NY 11377']},
#    'phone': '+17184268162',
#    'display_phone': '(718) 426-8162',
#    'distance': 5278.326423160265},
#   {'id': 'YIgBb6jb_KV0-nbYZ1oPig',
#    'alias': 'barn-na-thai-ridgewood',
#    'name': 'BARN NA THAI',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/GAI2zkiVLyalqT0cX3K3vg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barn-na-thai-ridgewood?adjust_creative=Oo7DNF-TUfNLFFtGvsZ4PA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Oo7DNF-TUfNLFFtGvsZ4PA',
#    'review_count': 16,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71012, 'longitude': -73.89958},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '6402 Fresh Pond Rd',
#     'address2': None,
#     'address3': None,
#     'city': 'RIDGEWOOD',
#     'zip_code': '11385',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['6402 Fresh Pond Rd', 'RIDGEWOOD, NY 11385']},
#    'phone': '+19293878065',
#    'display_phone': '(929) 387-8065',
#    'distance': 4594.843164144977},
#   {'id': 'SkYcO8FaqYgoP-66g58OMw',
#    'alias': 'thai-pot-forest-hills',
#    'name': 'Thai Pot',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Qu_oE3bTpWt-pJw8r4LXxw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/thai-pot-forest-hills?adjust_creative=Oo7DNF-TUfNLFFtGvsZ4PA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Oo7DNF-TUfNLFFtGvsZ4PA',
#    'review_count': 246,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 3.0,
#    'coordinates': {'latitude': 40.7247545048924,
#     'longitude': -73.8498401641846},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '103-07 Queens Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Forest Hills',
#     'zip_code': '11375',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['103-07 Queens Blvd', 'Forest Hills, NY 11375']},
#    'phone': '+17188973898',
#    'display_phone': '(718) 897-3898',
#    'distance': 788.0501952017784},
#   {'id': 'qrydcGQpeDP_1oFvx3qOeg',
#    'alias': 'somtum-der-new-york',
#    'name': 'Somtum Der',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/85AftnoxLOq0T0HKHPSdgg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/somtum-der-new-york?adjust_creative=Oo7DNF-TUfNLFFtGvsZ4PA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Oo7DNF-TUfNLFFtGvsZ4PA',
#    'review_count': 753,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7252151982238,
#     'longitude': -73.9842741682317},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '85 Ave A',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['85 Ave A', 'New York, NY 10009']},
#    'phone': '+12122608570',
#    'display_phone': '(212) 260-8570',
#    'distance': 11096.694980469541},
#   {'id': 'zENn0_yDJEdLoHyivXb2xw',
#    'alias': 'black-thai-jackson-heights-4',
#    'name': 'Black Thai',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kxJrShs7FqI0OaNE1d01aw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-thai-jackson-heights-4?adjust_creative=Oo7DNF-TUfNLFFtGvsZ4PA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Oo7DNF-TUfNLFFtGvsZ4PA',
#    'review_count': 290,
#    'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7553269, 'longitude': -73.8860092},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '81-16 Northern Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Jackson Heights',
#     'zip_code': '11372',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['81-16 Northern Blvd', 'Jackson Heights, NY 11372']},
#    'phone': '+17187798424',
#    'display_phone': '(718) 779-8424',
#    'distance': 3827.0847177331707}],
#  'total': 2600,
#  'region': {'center': {'longitude': -73.85284423828125,
#    'latitude': 40.73146603137887}}}

# %%
response.json()
# Out:
# {'businesses': [{'id': '6Ct7OeTRn4caY9g0swFBsw',
#    'alias': 'la-contenta-new-york',
#    'name': 'La Contenta',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FwZAyPgdKdPGQ8aAGKh3-w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-contenta-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 763,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.71873, 'longitude': -73.98691},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '102 Norfolk St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['102 Norfolk St', 'New York, NY 10002']},
#    'phone': '+12124324180',
#    'display_phone': '(212) 432-4180',
#    'distance': 4662.3743595723645},
#   {'id': 'ETgJqJHV7BW6pIr9Ox74sA',
#    'alias': 'amélie-new-york',
#    'name': 'Amélie',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/cSDgVuPMnJgMLTrTNSEXug/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/am%C3%A9lie-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 2702,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7327, 'longitude': -73.99766},
#    'transactions': ['restaurant_reservation', 'pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '22 W 8th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['22 W 8th St', 'New York, NY 10011']},
#    'phone': '+12125332962',
#    'display_phone': '(212) 533-2962',
#    'distance': 3464.4669936751793},
#   {'id': 'rp8S7scxOkVVeG7dNneMGQ',
#    'alias': 'l-artusi-new-york',
#    'name': "L'Artusi",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/HeDloBW-SnokWblGDuPrUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-artusi-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 1862,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73372, 'longitude': -74.00513},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '228 W 10th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['228 W 10th St', 'New York, NY 10014']},
#    'phone': '+12122555757',
#    'display_phone': '(212) 255-5757',
#    'distance': 3702.6967291210426},
#   {'id': 'ooYUO3Pq_qypc1NXFzeLYQ',
#    'alias': 'city-vineyard-new-york',
#    'name': 'City Vineyard',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/EQkP8Wd2bC_411mQMBtwXg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/city-vineyard-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 940,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7205582, 'longitude': -74.0118093},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '233 West St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['233 West St', 'New York, NY 10013']},
#    'phone': '+16466778350',
#    'display_phone': '(646) 677-8350',
#    'distance': 5193.210804405722},
#   {'id': 'DGhWO1sUWydVeR5j5ZZaMw',
#    'alias': 'la-grande-boucherie-new-york-2',
#    'name': 'La Grande Boucherie',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Lkc0FTvtITqYPKChk6A0Bw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-grande-boucherie-new-york-2?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 59,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76268, 'longitude': -73.98093},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '145 W 53rd St',
#     'address2': 'New York',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['145 W 53rd St', 'New York', 'New York, NY 10019']},
#    'phone': '+12125107714',
#    'display_phone': '(212) 510-7714',
#    'distance': 332.9066883809004},
#   {'id': 'bW3mY-voyav37nU0uaLmNQ',
#    'alias': 'dante-new-york',
#    'name': 'Dante',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KG1kurs7VTc48dQ-7tYGEw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dante-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 366,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72879, 'longitude': -74.00165},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '79-81 Macdougal St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['79-81 Macdougal St', 'New York, NY 10012']},
#    'phone': '+12129825275',
#    'display_phone': '(212) 982-5275',
#    'distance': 4000.901555055698},
#   {'id': 'xTnivXEdEtXrnhp-z4JGvg',
#    'alias': 'la-parisienne-new-york-5',
#    'name': 'La Parisienne',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/8i6Hgi2iOA06CgDK8ED4pQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-parisienne-new-york-5?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 507,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.70961, 'longitude': -74.0093799},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '9 Maiden Ln',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['9 Maiden Ln', 'New York, NY 10038']},
#    'phone': '+16467564911',
#    'display_phone': '(646) 756-4911',
#    'distance': 6196.411979923868},
#   {'id': 'ssGhu4n3emZ9kEPVf371IQ',
#    'alias': 'cookshop-new-york',
#    'name': 'Cookshop',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/PgQtbdoMTIaWFstO1wvJLQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cookshop-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 2120,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7454251, 'longitude': -74.0056084},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '156 10th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['156 10th Ave', 'New York, NY 10011']},
#    'phone': '+12129244440',
#    'display_phone': '(212) 924-4440',
#    'distance': 2799.3312228206055},
#   {'id': '8bIXIStb1SVu1sXYfcMH5g',
#    'alias': 'rubys-cafe-new-york-3',
#    'name': "Ruby's Cafe",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/O_UqkNF91Uh0ywxnLjclXA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rubys-cafe-new-york-3?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 108,
#    'categories': [{'alias': 'australian', 'title': 'Australian'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.730932, 'longitude': -73.988061},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '198 E 11th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['198 E 11th St', 'New York, NY 10003']},
#    'phone': '+16469984265',
#    'display_phone': '(646) 998-4265',
#    'distance': 3354.2406224100414},
#   {'id': 'XipQLDbyTl5tsLlyzAWzug',
#    'alias': 'jajaja-plantas-mexicana-new-york-2',
#    'name': 'Jajaja Plantas Mexicana',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/OkWKXxOZBLJO7hRjOlIMig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jajaja-plantas-mexicana-new-york-2?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 961,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7141530317142,
#     'longitude': -73.9904247969389},
#    'transactions': ['restaurant_reservation', 'pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '162 E Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['162 E Broadway', 'New York, NY 10002']},
#    'phone': '+16468835453',
#    'display_phone': '(646) 883-5453',
#    'distance': 5219.447623946914},
#   {'id': 'D2qV8sDdHEFlHbVz7VSHRQ',
#    'alias': 'black-tap-soho-new-york-3',
#    'name': 'Black Tap - Soho',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/3Jm6Riap3vSt7grwgISbvg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/black-tap-soho-new-york-3?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 1196,
#    'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.723794, 'longitude': -74.004193},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '529 Broome St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['529 Broome St', 'New York, NY 10013']},
#    'phone': '+19176393089',
#    'display_phone': '(917) 639-3089',
#    'distance': 4591.974972607585},
#   {'id': 'N5UY113nNpeKdLPv0cbMjQ',
#    'alias': 'the-wild-son-new-york',
#    'name': 'The Wild Son',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/bKbzwnDOl26D3aVzh-lj0A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-wild-son-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 504,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.727424, 'longitude': -73.985201},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '132 First Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['132 First Ave', 'New York, NY 10009']},
#    'phone': '+12127277900',
#    'display_phone': '(212) 727-7900',
#    'distance': 3690.7983417232585},
#   {'id': 'XsElXaLxUPKquI78poB8yw',
#    'alias': 'maison-pickle-new-york',
#    'name': 'Maison Pickle',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/AVfQDXs17sxfUWVz_z_0jQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/maison-pickle-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 1026,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7870473, 'longitude': -73.9781361},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2315 Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2315 Broadway', 'New York, NY 10024']},
#    'phone': '+12124969100',
#    'display_phone': '(212) 496-9100',
#    'distance': 2983.7799112880234},
#   {'id': '5MpWHGQ6Qc-M4q1KL_nioA',
#    'alias': 'bar-b-new-york',
#    'name': 'Bar B',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/rP6Gfe33cpkYe549tj_2BQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bar-b-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 184,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7395804, 'longitude': -73.999118},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '84 7th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['84 7th Ave', 'New York, NY 10011']},
#    'phone': '+12122291888',
#    'display_phone': '(212) 229-1888',
#    'distance': 2887.7164858736137},
#   {'id': 'OAqsZMbjv66nOMqlimnYuQ',
#    'alias': 'uva-new-york',
#    'name': 'Uva',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/OKw0xxKFXVRPNTRFx6v2Dg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/uva-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 2419,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7722, 'longitude': -73.95566},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1486 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10075',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1486 2nd Ave', 'New York, NY 10075']},
#    'phone': '+12124724552',
#    'display_phone': '(212) 472-4552',
#    'distance': 2341.9530202338674},
#   {'id': 'cTE0e96GYzet799EJeStoQ',
#    'alias': 'chama-mama-new-york',
#    'name': 'Chama Mama',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7F5i7rUgxBJip23brHPBiA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/chama-mama-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 339,
#    'categories': [{'alias': 'georgian', 'title': 'Georgian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7384, 'longitude': -73.99892},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '149 W 14th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['149 W 14th St', 'New York, NY 10011']},
#    'phone': '+16464389007',
#    'display_phone': '(646) 438-9007',
#    'distance': 2966.180331463606},
#   {'id': '9GBqbQ415CXaBa2gwHyFHQ',
#    'alias': 'sveta-new-york',
#    'name': 'Sveta',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1q_4Ssjl1SvHju5VHK3o8Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sveta-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 80,
#    'categories': [{'alias': 'russian', 'title': 'Russian'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72967, 'longitude': -74.00421},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '64 Carmine St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['64 Carmine St', 'New York, NY 10014']},
#    'phone': '+12122034106',
#    'display_phone': '(212) 203-4106',
#    'distance': 4021.345303287223},
#   {'id': 'zyyT2yiyxxamC-jKc0v-fg',
#    'alias': 'omars-kitchen-and-rum-bar-new-york',
#    'name': "Omar's Kitchen and Rum Bar",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3wyLFJ6QbIFnfoH91PTx5g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/omars-kitchen-and-rum-bar-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 81,
#    'categories': [{'alias': 'caribbean', 'title': 'Caribbean'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.720422, 'longitude': -73.984525},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '29A Clinton St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['29A Clinton St', 'New York, NY 10002']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 4458.053369804921},
#   {'id': 'nI1UYDCYUTt23TpGxqnLKg',
#    'alias': 'buddakan-new-york',
#    'name': 'Buddakan',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Y0PGrSO6gicAmxH4BhU3EA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/buddakan-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 4013,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7422762672197,
#     'longitude': -74.0048000961542},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '75 9th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['75 9th Ave', 'New York, NY 10011']},
#    'phone': '+12129896699',
#    'display_phone': '(212) 989-6699',
#    'distance': 2981.0496048609193},
#   {'id': 'xQ445GaWVN5Aa3sFX9OoIg',
#    'alias': 'buvette-new-york',
#    'name': 'Buvette',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9iK14ZmXBwgWWW0wigP0pw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/buvette-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 1765,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.732704, 'longitude': -74.004317},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '42 Grove St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['42 Grove St', 'New York, NY 10014']},
#    'phone': '+12122553590',
#    'display_phone': '(212) 255-3590',
#    'distance': 3753.3765765751923},
#   {'id': 'Rj2ACaJcbroJLPDhRhzvBw',
#    'alias': 'shuka-new-york-3',
#    'name': 'Shuka',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/s46eH_qJRLtAXaJguMg-VQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shuka-new-york-3?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 499,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72707, 'longitude': -74.00283},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '38 MacDougal St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['38 MacDougal St', 'New York, NY 10012']},
#    'phone': '+12124757500',
#    'display_phone': '(212) 475-7500',
#    'distance': 4217.946685020116},
#   {'id': '0IwdwNnbro5RLLIlaxyfpQ',
#    'alias': 'the-wilson-new-york-2',
#    'name': 'The Wilson',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4rn0I4qpKAIqPZAsMrhSew/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-wilson-new-york-2?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 167,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74587, 'longitude': -73.99265},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '132 W 27th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['132 W 27th St', 'New York, NY 10001']},
#    'phone': '+12125292671',
#    'display_phone': '(212) 529-2671',
#    'distance': 1987.2559059837151},
#   {'id': 'Xd_l7jtUAZZAAvK8-mI2Jw',
#    'alias': 'the-smith-new-york-7',
#    'name': 'The Smith',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/iRt2bcEEBQgy6qQQwlPvtQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-smith-new-york-7?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 1017,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.74424, 'longitude': -73.98878},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1150 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10010',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1150 Broadway', 'New York, NY 10010']},
#    'phone': '+12126854500',
#    'display_phone': '(212) 685-4500',
#    'distance': 1977.2193388418018},
#   {'id': 'RzKR9QcYP03EQ_8DxTxowg',
#    'alias': 'barrio-chino-new-york',
#    'name': 'Barrio Chino',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/8PdXnElPeE7PVXLDuU6lKg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/barrio-chino-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 1109,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.718022, 'longitude': -73.990026},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '253 Broome St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['253 Broome St', 'New York, NY 10002']},
#    'phone': '+12122286710',
#    'display_phone': '(212) 228-6710',
#    'distance': 4791.069494550982},
#   {'id': 'nrwOQSXoRXfAYhkdjiUk8g',
#    'alias': 'toro-loco-new-york',
#    'name': 'Toro Loco',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/WXWUVnk5u1XaZV-fzAYV8g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/toro-loco-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 254,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70421, 'longitude': -74.01208},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '15 Stone St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10004',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['15 Stone St', 'New York, NY 10004']},
#    'phone': '+19172620444',
#    'display_phone': '(917) 262-0444',
#    'distance': 6845.025266309657},
#   {'id': 'vgg1dvDP-9tFWSacN4q0nA',
#    'alias': 'coppelia-new-york',
#    'name': 'Coppelia',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/sXzxZcMCd5ZH2RzZ26QJZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/coppelia-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 1352,
#    'categories': [{'alias': 'cuban', 'title': 'Cuban'},
#     {'alias': 'latin', 'title': 'Latin American'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7389111700125,
#     'longitude': -73.9999985153443},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '207 W 14th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['207 W 14th St', 'New York, NY 10011']},
#    'phone': '+12128585001',
#    'display_phone': '(212) 858-5001',
#    'distance': 2981.793142335955},
#   {'id': 'UJe9_p6NEl0kA6xHVo5PKw',
#    'alias': 'amelie-new-york-2',
#    'name': 'Amelie',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Dn-MbEQvRT8HzHp_qTf-MQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/amelie-new-york-2?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 209,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.78875, 'longitude': -73.97464},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '566 Amsterdam Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['566 Amsterdam Ave', 'New York, NY 10024']},
#    'phone': '+16464227167',
#    'display_phone': '(646) 422-7167',
#    'distance': 3191.820589668884},
#   {'id': '0FaLilJs2VN83hOEBcBnPg',
#    'alias': 'au-zaatar-new-york',
#    'name': "Au Za'atar",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Qwjkj1qkdcOKKOIGwbYutg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/au-zaatar-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 965,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'lebanese', 'title': 'Lebanese'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.728901, 'longitude': -73.981185},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '188 Avenue A',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['188 Avenue A', 'New York, NY 10009']},
#    'phone': '+12122545660',
#    'display_phone': '(212) 254-5660',
#    'distance': 3489.281528088423},
#   {'id': 'PHMkwS5nmo4IUXbcg0OcAg',
#    'alias': 'jajaja-plantas-mexicana-new-york',
#    'name': 'Jajaja Plantas Mexicana',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uWbBN6yZcR5TMFY0W0RmYQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jajaja-plantas-mexicana-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 235,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72979, 'longitude': -74.00455},
#    'transactions': ['restaurant_reservation', 'pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '63 Carmine St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['63 Carmine St', 'New York, NY 10014']},
#    'phone': '+19172620184',
#    'display_phone': '(917) 262-0184',
#    'distance': 4026.1568602033262},
#   {'id': 'xMUZfoyzyJoTfZxrEZus4Q',
#    'alias': 'moms-kitchen-and-bar-new-york',
#    'name': "Mom's Kitchen & Bar",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/2em4dLRX21eieAsYXp_xUw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/moms-kitchen-and-bar-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 755,
#    'categories': [{'alias': 'comfortfood', 'title': 'Comfort Food'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.76247, 'longitude': -73.9901},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '701 9th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10019',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['701 9th Ave', 'New York, NY 10019']},
#    'phone': '+16466570080',
#    'display_phone': '(646) 657-0080',
#    'distance': 1007.0432521810978},
#   {'id': 'riykDqJw_NPGssLgqCeD-Q',
#    'alias': 'aunt-jakes-new-york-4',
#    'name': "Aunt Jake's",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9Wvs6ueo5Sn-aVEmRwJ05g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/aunt-jakes-new-york-4?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 38,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'pastashops', 'title': 'Pasta Shops'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.774587, 'longitude': -73.954513},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '1555 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1555 2nd Ave', 'New York, NY 10028']},
#    'phone': '+19172615040',
#    'display_phone': '(917) 261-5040',
#    'distance': 2577.0827972409556},
#   {'id': 'fuS39acPaRi38DhSSwEI4Q',
#    'alias': 'felice-new-york-6',
#    'name': 'Felice',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/RjmwyXZWgYk0IPqigCTjzw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/felice-new-york-6?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 370,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'tuscan', 'title': 'Tuscan'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.70789, 'longitude': -74.00712},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '15 Gold St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10038',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['15 Gold St', 'New York, NY 10038']},
#    'phone': '+12127855950',
#    'display_phone': '(212) 785-5950',
#    'distance': 6299.336651839251},
#   {'id': 'aSFBv64GBpMOFPqIleeQFQ',
#    'alias': 'lure-fishbar-new-york-2',
#    'name': 'Lure Fishbar',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/uUa1NJdRR4iljdfu6D1V8A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lure-fishbar-new-york-2?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 1665,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'sushi', 'title': 'Sushi Bars'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.724612166991, 'longitude': -73.998574708004},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '142 Mercer St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['142 Mercer St', 'New York, NY 10012']},
#    'phone': '+12124317676',
#    'display_phone': '(212) 431-7676',
#    'distance': 4304.947803544696},
#   {'id': 'C-8mGN7lt5rIraO5n-15ug',
#    'alias': 'the-smith-new-york-2',
#    'name': 'The Smith',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/fGAZCdyPI8qil5boCzidBA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-smith-new-york-2?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 2676,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.755165, 'longitude': -73.967868},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '956 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10022',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['956 2nd Ave', 'New York, NY 10022']},
#    'phone': '+12126442700',
#    'display_phone': '(212) 644-2700',
#    'distance': 1057.0229649315834},
#   {'id': 'hmG5OnHEe2vQRrQxez0U9w',
#    'alias': 'worthwild-new-york',
#    'name': 'Worthwild',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/KVUdxRPC1BJsImaGRb7bng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/worthwild-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 72,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74428, 'longitude': -74.00272},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '156 9th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['156 9th Ave', 'New York, NY 10011']},
#    'phone': '+17189429385',
#    'display_phone': '(718) 942-9385',
#    'distance': 2697.584062175352},
#   {'id': 's3jou_L_LVYGkNHiuhjlew',
#    'alias': 'boucherie-west-village-new-york-3',
#    'name': 'Boucherie West Village',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/gGTUB2AHF7sK5u-wdjO8DA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/boucherie-west-village-new-york-3?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 1537,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'steak', 'title': 'Steakhouses'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.733063, 'longitude': -74.0028772},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$$',
#    'location': {'address1': '99 7th Ave S',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['99 7th Ave S', 'New York, NY 10014']},
#    'phone': '+12128371616',
#    'display_phone': '(212) 837-1616',
#    'distance': 3651.3436314400974},
#   {'id': 'mWS4umRg2AyykyAClMrIRw',
#    'alias': 'the-penrose-new-york',
#    'name': 'The Penrose',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YDYUed0l4okORNytlggAyQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-penrose-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 1203,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.775427, 'longitude': -73.953115},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1590 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1590 2nd Ave', 'New York, NY 10028']},
#    'phone': '+12122032751',
#    'display_phone': '(212) 203-2751',
#    'distance': 2723.883238157801},
#   {'id': 'wGFSTTB6b4MHJJUzBnVJeg',
#    'alias': 'top-thai-greenwich-new-york',
#    'name': 'Top Thai Greenwich',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/4xK8iIj2rZrRvP9MMG7yOA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/top-thai-greenwich-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 1525,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'halal', 'title': 'Halal'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.729771, 'longitude': -73.999392},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '235 Sullivan St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['235 Sullivan St', 'New York, NY 10012']},
#    'phone': '+16467264418',
#    'display_phone': '(646) 726-4418',
#    'distance': 3815.4646277956435},
#   {'id': 'VLGmFHE4s0Sfu0piMVQa1Q',
#    'alias': 'hold-fast-kitchen-and-spirits-new-york',
#    'name': 'Hold Fast Kitchen and Spirits',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/A0KyqQHE3euVnUVVDhqrlg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hold-fast-kitchen-and-spirits-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 362,
#    'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.76064, 'longitude': -73.99023},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '364 W 46th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10036',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['364 W 46th St', 'New York, NY 10036']},
#    'phone': '+19172616691',
#    'display_phone': '(917) 261-6691',
#    'distance': 991.6684952173948},
#   {'id': 'twHJyFgUSd7wzioKQjE7Jw',
#    'alias': 'galli-new-york-5',
#    'name': 'Galli',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/NriJMGzJm4mZn-Pj2oRm3Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/galli-new-york-5?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 950,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72161, 'longitude': -74.00127},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '45 Mercer St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10013',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['45 Mercer St', 'New York, NY 10013']},
#    'phone': '+12129669288',
#    'display_phone': '(212) 966-9288',
#    'distance': 4699.174505441503},
#   {'id': '7rxg-tWPc1jK7Cikn5R86g',
#    'alias': 'hi-collar-new-york-2',
#    'name': 'Hi-Collar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6DAtn_pu8hX79LB3sSlFtw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hi-collar-new-york-2?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 599,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.729564, 'longitude': -73.98786},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '231 E 9th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['231 E 9th St', 'New York, NY 10003']},
#    'phone': '+12127777018',
#    'display_phone': '(212) 777-7018',
#    'distance': 3498.241677612774},
#   {'id': 'FZpm4_fbd6P984foOUejWg',
#    'alias': 'jongro-bbq-new-york-3',
#    'name': 'Jongro BBQ',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/G0IeLwvmss-QsBu1ZWEIfg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/jongro-bbq-new-york-3?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 1991,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.747514, 'longitude': -73.986884},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '22 W 32nd St',
#     'address2': 'Fl 2',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10001',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['22 W 32nd St', 'Fl 2', 'New York, NY 10001']},
#    'phone': '+12124732233',
#    'display_phone': '(212) 473-2233',
#    'distance': 1578.987816539336},
#   {'id': '26E3j9l0XW_onVIUP-ThCw',
#    'alias': 'heidis-house-by-the-side-of-the-road-new-york-2',
#    'name': "Heidi's House By The Side Of The Road",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/29Z6Thcc591JVESABqZafQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/heidis-house-by-the-side-of-the-road-new-york-2?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 623,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.772189, 'longitude': -73.955029},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '308 E 78th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10075',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['308 E 78th St', 'New York, NY 10075']},
#    'phone': '+12122490069',
#    'display_phone': '(212) 249-0069',
#    'distance': 2383.28550485997},
#   {'id': 'PqqnNrUtU7XTKQvUM4cyqQ',
#    'alias': 'bar-verde-new-york',
#    'name': 'Bar Verde',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YytQBbTEFeNme8UJoH_jWQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bar-verde-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 271,
#    'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7260849061034,
#     'longitude': -73.9897361397743},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '65 2nd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['65 2nd Ave', 'New York, NY 10003']},
#    'phone': '+12127776965',
#    'display_phone': '(212) 777-6965',
#    'distance': 3911.344763787452},
#   {'id': 'J3NT61-AH5d5Gu5tFJhYSw',
#    'alias': 'the-cabin-nyc-new-york-2',
#    'name': 'The Cabin NYC',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dc54M8OrhvbJLRkuSmdmHw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-cabin-nyc-new-york-2?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 251,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72393, 'longitude': -73.98383},
#    'transactions': ['restaurant_reservation', 'pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '205 E 4th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['205 E 4th St', 'New York, NY 10009']},
#    'phone': '+12127770454',
#    'display_phone': '(212) 777-0454',
#    'distance': 4055.8669880946763},
#   {'id': 'RPP_wHhM8yZYIP5W-YHk6Q',
#    'alias': 'fumo-new-york-3',
#    'name': 'Fumo',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/nqabsyMKaqjqCFul1yerEg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fumo-new-york-3?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 79,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.80284, 'longitude': -73.968119},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '2791 Broadway',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10025',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['2791 Broadway', 'New York, NY 10025']},
#    'phone': '+16468222921',
#    'display_phone': '(646) 822-2921',
#    'distance': 4819.612835669943},
#   {'id': 'xTWpl9DgIkkr5B8h8_xUpA',
#    'alias': 'lokal-83-mediterranean-kitchen-new-york-2',
#    'name': 'Lokal 83 Mediterranean Kitchen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/GcrWkRztvAX2S-Eb1PtkzQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lokal-83-mediterranean-kitchen-new-york-2?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 342,
#    'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'turkish', 'title': 'Turkish'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7842696, 'longitude': -73.9734941},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '473 Columbus Ave',
#     'address2': '83rd street',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10024',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['473 Columbus Ave',
#      '83rd street',
#      'New York, NY 10024']},
#    'phone': '+12125955554',
#    'display_phone': '(212) 595-5554',
#    'distance': 2707.7750908833113},
#   {'id': 'I6KHYESZdZQz0fnMaMyIpQ',
#    'alias': 'zusik-new-york-2',
#    'name': 'Zusik',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/nTiSFnBWujKMowrtQNB1mw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/zusik-new-york-2?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 167,
#    'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.738532, 'longitude': -74.000368},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '202 W 14th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10011',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['202 W 14th St', 'New York, NY 10011']},
#    'phone': '+16463705331',
#    'display_phone': '(646) 370-5331',
#    'distance': 3027.8374303918968},
#   {'id': 'JYNBy2r3LVhJbLHE1bASfg',
#    'alias': 'the-smith-new-york-3',
#    'name': 'The Smith',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/wcwUFAyZ1X-thnem2s6WPw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-smith-new-york-3?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 1740,
#    'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7716201269986,
#     'longitude': -73.9818377981476},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '1900 Broadway',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10023',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1900 Broadway', 'New York, NY 10023']},
#    'phone': '+12124965700',
#    'display_phone': '(212) 496-5700',
#    'distance': 1298.9737992359637},
#   {'id': 'ZOa13veZkzGjA-x3kMfOmA',
#    'alias': '4-charles-prime-rib-new-york',
#    'name': '4 Charles Prime Rib',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/4Agj-I-o8kDf7nAoK1ZiWQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/4-charles-prime-rib-new-york?adjust_creative=bVX1Jsfp4dkIOqw5HOVplg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=bVX1Jsfp4dkIOqw5HOVplg',
#    'review_count': 270,
#    'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.73513, 'longitude': -74.00065},
#    'transactions': ['delivery'],
#    'price': '$$$',
#    'location': {'address1': '4 Charles St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['4 Charles St', 'New York, NY 10014']},
#    'phone': '+12125615992',
#    'display_phone': '(212) 561-5992',
#    'distance': 3353.6173099853013}],
#  'total': 3000,
#  'region': {'center': {'longitude': -73.97850036621094,
#    'latitude': 40.76021491079617}}}

# %% [markdown]
# Using one of the methods above load the response data and assign it to a variable `data`.

# %%
data = response.json()

# %% [markdown]
# What are the keys in this dictionary and the datatypes of their values.

# %%
# your code here
data.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %% [markdown]
# How many results did our query return?

# %%
data['total']
# Out:
# 2700

# %% [markdown]
# How many businesses were returned from the API call?

# %%
len(data['businesses'])
# Out:
# 50

# %%
def yelp_call(url_params):
    response = requests.get(url, headers=headers, params=url_params)
    return response.json()['businesses']

# %% [markdown]
# ### Parsing the Results
#
# There are a lot of key-value pairs for each business. Many of which we do not care about. Let's create a simple parser of this data that will return a list with the name, display_address, and one other data point of your choice. First we want to assign one of the businesses to the `business` variable. Once we cna properly parse oonne business  we can use a loop to do them all.

# %%
business = data['businesses'][0]

# %%
business
# Out:
# {'id': 'xi_QX5uArqDM4LeL4WIv1Q',
#  'alias': 'lis-kitchen-bronx',
#  'name': "Li's Kitchen",
#  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/sVN8idX4C2o_ycdyNS7y3Q/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/lis-kitchen-bronx?adjust_creative=Oo7DNF-TUfNLFFtGvsZ4PA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Oo7DNF-TUfNLFFtGvsZ4PA',
#  'review_count': 35,
#  'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#  'rating': 4.0,
#  'coordinates': {'latitude': 40.8634617, 'longitude': -73.8584642},
#  'transactions': ['pickup', 'delivery'],
#  'price': '$$',
#  'location': {'address1': '2515 Williamsbridge Rd',
#   'address2': '',
#   'address3': '',
#   'city': 'Bronx',
#   'zip_code': '10469',
#   'country': 'US',
#   'state': 'NY',
#   'display_address': ['2515 Williamsbridge Rd', 'Bronx, NY 10469']},
#  'phone': '+17185191881',
#  'display_phone': '(718) 519-1881',
#  'distance': 1652.539115314742}

# %% [markdown]
# Rember we want the following pieces of information:
# name, display_address, and one other data point of your choice

# %%
biz_tuple = (business['name'], business['location']['zip_code'],business['rating'])

# %%
biz_tuple
# Out:
# ("Li's Kitchen", '10469', 4.0)

# %% [markdown]
# Now that we know how to do this for one business. Let create a function that recieves the list of businesses and returns a list of tuples with the important information.

# %%
def parse_data(list_of_data):
    # create a container to hold our parsed data
    businesses = []
    # loop through our business
    for business in list_of_data:      
    # parse each individual business into a tuple
        biz_tuple = (business['name'], 
                     business['location']['zip_code'],
                     business['rating'])
    # add each individual business tuple to our data container
        businesses.append(biz_tuple)
    # return the container with all of the parsed results
    return businesses

# %%
parsed_results = parse_data(data['businesses'])

# %% [markdown]
# Take the parsed results and put them in a Dataframe.

# %%
parsed_results
# Out:
# [("Li's Kitchen", '10469', 4.0),
#  ('Best Chinese Restaurant', '10475', 4.5),
#  ('China Mia', '10467', 4.0),
#  ('Empire Wok', '10462', 2.5),
#  ('Kai Sushi Asian Fusion', '10461', 4.0),
#  ('Halal Fresh', '10462', 5.0),
#  ('Golden Chef', '10461', 4.5),
#  ('Mei Chung Mei Restaurant', '10463', 4.0),
#  ('China Pavilion', '10461', 4.0),
#  ('Xing Wang No. 1', '10453', 4.5),
#  ('Yung Hsin', '10460', 5.0),
#  ('Six Happiness Restaurant', '10461', 4.0),
#  ("New General Tso's Restaurant", '10472', 4.0),
#  ('Kawah Chinese Restaurant', '10458', 4.0),
#  ('King Hing Restaurant', '10461', 4.0),
#  ('Dynasty', '10462', 3.5),
#  ('Panda Restaurant', '10462', 3.5),
#  ('Hong Kong Restaurant', '10461', 3.5),
#  ("New King's Wok Kitchen", '10471', 4.0),
#  ("Mr.Q's", '10461', 3.0),
#  ('Boe Lee Chinese', '10462', 3.5),
#  ('Mei Mei Restaurant', '10468', 3.5),
#  ('Moon Star Grill', '10463', 4.0),
#  ('La Nueva Win Hing Restaurant', '10452', 4.0),
#  ('Sabrosura 2', '10472', 4.0),
#  ("Xing & Hui Linda's Kitchen", '10465', 4.0),
#  ('Number 1 Chinese Restaurant', '10467', 4.5),
#  ('Double Dragon Restaurant', '10468', 3.5),
#  ('Musas Chinese Resturaunt', '10462', 4.0),
#  ('Anise', '10463', 3.5),
#  ('Lucky Star Chinese Restaurant', '10472', 3.5),
#  ('Great Wall', '10458', 5.0),
#  ('China Palace', '10461', 3.0),
#  ('Pearl of China', '10461', 3.5),
#  ('Happy Dragon', '10467', 4.0),
#  ('Xiun Wei Restaurant', '10461', 5.0),
#  ('King Wok', '10467', 3.0),
#  ('Quality Chef Chinese Restaurant', '10465', 3.0),
#  ('Jade Garden', '10032', 3.5),
#  ("Jen's Restaurant", '10461', 3.5),
#  ('China One', '10467', 4.0),
#  ('Golden Palace Chinese Restaurant', '10473', 3.5),
#  ('King Dragon', '10452', 4.5),
#  ('Sabrosura Restaurant', '10462', 3.5),
#  ('Green Dragon Restaurant', '10465', 3.0),
#  ('Panda Express', '10468', 2.0),
#  ('Good Taste Chinese Restaurant', '10451', 3.5),
#  ('New Dragon Star Chinese Kitchen', '10466', 4.0),
#  ('Fresh Tortillas', '10461', 3.5),
#  ('Eastern Style Chinese', '10456', 4.0)]

# %%
import pandas as pd

# %%
pd.DataFrame(parsed_results)
# Out:
#                                    0      1    2
# 0                       Li's Kitchen  10469  4.0
# 1            Best Chinese Restaurant  10475  4.5
# 2                          China Mia  10467  4.0
# 3                         Empire Wok  10462  2.5
# 4             Kai Sushi Asian Fusion  10461  4.0
# 5                        Halal Fresh  10462  5.0
# 6                        Golden Chef  10461  4.5
# 7           Mei Chung Mei Restaurant  10463  4.0
# 8                     China Pavilion  10461  4.0
# 9                    Xing Wang No. 1  10453  4.5
# 10                         Yung Hsin  10460  5.0
# 11          Six Happiness Restaurant  10461  4.0
# 12      New General Tso's Restaurant  10472  4.0
# 13          Kawah Chinese Restaurant  10458  4.0
# 14              King Hing Restaurant  10461  4.0
# 15                           Dynasty  10462  3.5
# 16                  Panda Restaurant  10462  3.5
# 17              Hong Kong Restaurant  10461  3.5
# 18            New King's Wok Kitchen  10471  4.0
# 19                            Mr.Q's  10461  3.0
# 20                   Boe Lee Chinese  10462  3.5
# 21                Mei Mei Restaurant  10468  3.5
# 22                   Moon Star Grill  10463  4.0
# 23      La Nueva Win Hing Restaurant  10452  4.0
# 24                       Sabrosura 2  10472  4.0
# 25        Xing & Hui Linda's Kitchen  10465  4.0
# 26       Number 1 Chinese Restaurant  10467  4.5
# 27          Double Dragon Restaurant  10468  3.5
# 28          Musas Chinese Resturaunt  10462  4.0
# 29                             Anise  10463  3.5
# 30     Lucky Star Chinese Restaurant  10472  3.5
# 31                        Great Wall  10458  5.0
# 32                      China Palace  10461  3.0
# 33                    Pearl of China  10461  3.5
# 34                      Happy Dragon  10467  4.0
# 35               Xiun Wei Restaurant  10461  5.0
# 36                          King Wok  10467  3.0
# 37   Quality Chef Chinese Restaurant  10465  3.0
# 38                       Jade Garden  10032  3.5
# 39                  Jen's Restaurant  10461  3.5
# 40                         China One  10467  4.0
# 41  Golden Palace Chinese Restaurant  10473  3.5
# 42                       King Dragon  10452  4.5
# 43              Sabrosura Restaurant  10462  3.5
# 44           Green Dragon Restaurant  10465  3.0
# 45                     Panda Express  10468  2.0
# 46     Good Taste Chinese Restaurant  10451  3.5
# 47   New Dragon Star Chinese Kitchen  10466  4.0
# 48                   Fresh Tortillas  10461  3.5
# 49             Eastern Style Chinese  10456  4.0
